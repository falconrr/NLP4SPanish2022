# %% [markdown]
# # spaCy: una libreria *open source* para NLP en Python

# %% [markdown]
# spaCy está diseñado para realizar las tareas de NLP más comunes en la industria de manera fácil, ágil y versatil. Para esta actividad veremos cuatro funcionalidades de la librería:
# 1. Part of Speech Tagger: etiqueta la función gramatical a cada palabra
# 2. Dependency Parser: divide los elementos de la oración mediante dependencias sintácticas
# 3. Named entity recognition: reconocimiento de entidades de conocimiento público
# 4. Similitud textual: computa la similitud de contenido de varios textos

# %%
# !pip install -U spacy  # instalamos la última version de spaCy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Collecting spacy
#   Downloading spacy-3.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 4.9 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 25.8 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.5 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 40.8 MB/s
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.16-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 48.8 MB/s
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 50.0 MB/s
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.2 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: typing-extensions, catalogue, typer, srsly, smart-open, pydantic, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 6.0.0
#     Uninstalling smart-open-6.0.0:
#       Successfully uninstalled smart-open-6.0.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0+zzzcolab20220506162203 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed catalogue-2.0.7 langcodes-3.3.0 pathy-0.6.1 pydantic-1.8.2 smart-open-5.2.1 spacy-3.3.0 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 thinc-8.0.16 typer-0.4.1 typing-extensions-3.10.0.2

# %%
# !python -m spacy info # podemos ver la versión más actualizada aquí
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.3.0
# Location         /usr/local/lib/python3.7/dist-packages/spacy
# Platform         Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic
# Python version   3.7.13
# Pipelines

# %%
# ahora debemos debemos descargar uno de los modelos pre-entrenados para español. Aquí instalamos el más pequeño.
# Si deseas otro módelo puedes utilizar uno de estos: https://spacy.io/models/es
# !python -m spacy download es_core_news_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.3.0/es_core_news_sm-3.3.0-py3-none-any.whl (12.9 MB)
#      |████████████████████████████████| 12.9 MB 5.5 MB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from es-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (1.21.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (0.4.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (8.0.16)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (1.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (0.9.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (0.6.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (57.4.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->es-core-news-sm==3.3.0) (2.0.1)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
import spacy # importamos el módulo

# %%
nlp = spacy.load("es_core_news_sm") # asignamos el modelo a una variable

# %%
doc = nlp(u'Mateo está en su casa y está en clase.') # hacemos una prueba de tokenización
for token in doc: # imprimimos cada token en cada línea
    print(token)
# Out:
# Mateo
# está
# en
# su
# casa
# y
# está
# en
# clase
# .

# %% [markdown]
# ## 1. Part of Speech Tagging

# %% [markdown]
# Para esta primera actividad vamos a etiquetar cada palabra de la oración con su función gramatical. Esto se llama [Part of Speech Tagging](https://spacy.io/usage/linguistic-features) y es una de las tareas de NLP más comunes en la industria.

# %%
# para obtener esta información de la oración ejecutamos el siguiente código
doc2 = nlp(u'La segunda vez que fui al otro lado del charco fue para visitar a un amigo en españa') # oración tomada del corpus UpperBeginner.txt
for token in doc2: 
    print("\t".join( (token.text, token.lemma_, token.tag_) ) )
# Out:
# La	el	DET
# segunda	segundo	ADJ
# vez	vez	NOUN
# que	que	PRON
# fui	ir	AUX
# al	al	ADP
# otro	otro	DET
# lado	lado	NOUN
# del	del	ADP
# charco	charco	NOUN
# fue	ser	AUX
# para	para	ADP
# visitar	visitar	VERB
# a	a	ADP
# un	uno	DET
# amigo	amigo	NOUN
# en	en	ADP
# españa	españa	PROPN

# %% [markdown]
# Lo primero que vemos en la tabla de arriba es el token mismo. Luego, el lema y, por último, la etiqueta con la función gramatical dentrode la oración. ¿Puedes decifrar cada etiqueta?
#
# Puedes encontrar más funcionalidades e información [aquí](https://spacy.io/usage/linguistic-features)

# %% [markdown]
# ## 2. Dependency Parse

# %% [markdown]
# Similar al *POS Tagger*, spaCy también nos muestra la relación sintactica de cada palabra dentro de la oración mediante una gramática de dependencias (Dependency Grammar). En la *dependency grammar* la estructura sintáctica de una oración se describe mediante un conjunto de arcos binarios que contienen las relaciones gramaticales entre las palabras.

# %%
doc3 = nlp(u'Andrea Nett pone la sal del Himalaya en la mesa grande')
print ("{:<15} | {:<8} | {:<15} | {:<20}".format('Token','Relación','Cabeza', 'Dependencia'))
print ("-" * 70)

for token in doc3:
  # Print the token, dependency nature, head and all dependents of the token
  print ("{:<15} | {:<8} | {:<15} | {:<20}"
         .format(str(token.text), str(token.dep_), str(token.head.text), str([child for child in token.children])))
# Out:
# Token           | Relación | Cabeza          | Dependencia
# ----------------------------------------------------------------------
# Andrea          | nsubj    | pone            | [Nett]
# Nett            | flat     | Andrea          | []
# pone            | ROOT     | pone            | [Andrea, sal, mesa]
# la              | det      | sal             | []
# sal             | obj      | pone            | [la, Himalaya]
# del             | case     | Himalaya        | []
# Himalaya        | nmod     | sal             | [del]
# en              | case     | mesa            | []
# la              | det      | mesa            | []
# mesa            | obl      | pone            | [en, la, grande]
# grande          | amod     | mesa            | []

# %% [markdown]
# En la primera columna vemos el texto. Luego, vemos su relación de dependencia con el token de la tercera columna. Luego vemos la principal categoria gramatical del *head*. Por último, se muestran los *hijos* de cada palabra (donde sea acertado).
#
# Estas relaciones sintáticas las podemos ver gráficamente:

# %%
from spacy import displacy # importamos el módulo gráfico de spaCy.

# %%
displacy.render(doc3, style='dep', jupyter=True, options={"distance": 85}) # ejecutamos este código. Nota la opción 'dep'.
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="cbd3a10b782d4b8f981bc84a51e62c58-0" class="displacy" width="985" height="264.5" direction="ltr" style="max-width: none; height: 264.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Andrea</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="135">Nett</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="220">pone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="220">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="305">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="390">sal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="390">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="475">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="475">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="560">Himalaya</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="560">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="645">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="645">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="730">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="815">mesa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="815">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="900">grande</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-0" stroke-width="2px" d="M70,129.5 C70,44.5 215.0,44.5 215.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,131.5 L62,119.5 78,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-1" stroke-width="2px" d="M70,129.5 C70,87.0 125.0,87.0 125.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M125.0,131.5 L133.0,119.5 117.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-2" stroke-width="2px" d="M325,129.5 C325,87.0 380.0,87.0 380.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M325,131.5 L317,119.5 333,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-3" stroke-width="2px" d="M240,129.5 C240,44.5 385.0,44.5 385.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,131.5 L393.0,119.5 377.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-4" stroke-width="2px" d="M495,129.5 C495,87.0 550.0,87.0 550.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M495,131.5 L487,119.5 503,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-5" stroke-width="2px" d="M410,129.5 C410,44.5 555.0,44.5 555.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M555.0,131.5 L563.0,119.5 547.0,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-6" stroke-width="2px" d="M665,129.5 C665,44.5 810.0,44.5 810.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M665,131.5 L657,119.5 673,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-7" stroke-width="2px" d="M750,129.5 C750,87.0 805.0,87.0 805.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750,131.5 L742,119.5 758,119.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cbd3a10b782d4b8f981bc84a51e62c58-0-8" stroke-width="2px" d="M240,129.5 C240,2.0 815.0,2.0 815.0,129.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cbd3a10b782d4b8f981bc84a51e

# %% [markdown]
# ## 3. Named Entity recognition

# %% [markdown]
# Como su nombre lo indica, en *Named Entity Recognition* le pedimos a spaCy que reconozca entidades, lugares, personas, fechas, etc., que son de conocimiento público. SpaCy encontrará tantas entidades como estén disponibles en el modelo de español que cargamos a la memoria.

# %%
doc4 = nlp(u'En los años de 2006 yo estaba en vacaciones en Florida con mi familia') # oración adicional

# %%
for ent in doc4.ents: # hacemos un for loop para que imprima la siguiente información
    print(ent.text, ent.start_char, ent.end_char, ent.label_) # 1. entidad, 2. número de caracter de inicio, 3. número de caracter final, 4. etiqueta
# Out:
# Florida 47 54 LOC

# %%
displacy.render(doc4, style='ent', jupyter=True) # visualización!
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beyoncé
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  está casada con
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay Z
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# </div></span>

# %% [markdown]
# ## 4. Similitud textual

# %% [markdown]
# Aquí computaremos la similitud en contexto de dos o más textos. El programa va a convertir las palabras en vectores o representaciones númericas. Luego, va a modelar la probabilidad de que dos textos aparezcan en ambos contextos.

# %%
# Debemos descargar el modelo mediano de español. Este modelo es más grande y útil para esta actividad.
# !python -m spacy download es_core_news_md
nlp2 = spacy.load("es_core_news_md")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-md==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.3.0/es_core_news_md-3.3.0-py3-none-any.whl (42.3 MB)
#      |████████████████████████████████| 42.3 MB 2.9 MB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from es-core-news-md==3.3.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (1.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (8.0.16)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (0.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (0.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (0.9.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (4.64.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.23.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (1.21.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.10.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (21.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2022.5.18.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->es-core-news-md==3.3.0) (2.0.1)
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-3.3.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %%
# escribimos oraciones o pegamos un texto entre las comillas
texto1 = nlp2("Me gustan las hamburguesas y las papas fritas.")
texto2 = nlp2("Los perros calientes son comidas rápidas.")

# %%
# Computamos la similitud de los dos documentos
print(texto1, "<->", texto2, texto1.similarity(texto2))
# Out:
# Me gustan las hamburguesas y las papas fritas. <-> Los perros calientes son comidas rápidas. 0.4402628376724563

# %% [markdown]
# En este caso las dos oraciones tienen una similitud de 36%. También podemos evaluar la similitud de dos palabras o frases.
#
# En este caso, la cuenta de los tokens de la oración empieza desde cero (0).

# %%
# Similaritud de tokens y frases
hamburguesas = texto1[3]
papas_fritas = texto1[6:8]
print(hamburguesas, "<->", papas_fritas, hamburguesas.similarity(papas_fritas))
# Out:
# hamburguesas <-> papas fritas 0.7660989165306091

# %% [markdown]
# ## *Ahora tú!*
#
# Practica lo que aprendiste con diferentes oraciones de tu ensayo sobre Gabriel García Marquez.

# %% [markdown]
# ### Part of Speech Tagging ⚡

# %%
texto3 = nlp(u'Donald Trump y Joseph Biden estaban los canidades de presidente de Los Estados Unidos en el elección de 2020.') # COMPLETAR
for token in texto3: # COMPLETAR
    print("\t".join( (token.text, token.lemma_, token.tag_) ) )
# Out:
# Donald	Donald	PROPN
# Trump	Trump	PROPN
# y	y	CCONJ
# Joseph	Joseph	PROPN
# Biden	Biden	PROPN
# estaban	estar	VERB
# los	el	DET
# canidades	canidad	NOUN
# de	de	ADP
# presidente	presidente	NOUN
# de	de	ADP
# Los	el	DET
# Estados	Estados	PROPN
# Unidos	Unidos	PROPN
# en	en	ADP
# el	el	DET
# elección	elección	NOUN
# de	de	ADP
# 2020	2020	NOUN
# .	.	PUNCT

# %% [markdown]
# ¿Puedes decifrar cada etiqueta? Puedes encontrar la descripción de cada etiqueta [aquí](https://github.com/explosion/spaCy/blob/master/spacy/glossary.py)

# %% [markdown]
# ### Dependency Parser ⚡

# %%
??? = nlp(u'???') #COMPLETAR
print ("{:<15} | {:<8} | {:<15} | {:<20}".format('Token','Relación','Cabeza', 'Dependencia'))
print ("-" * 70)

for token in ???: #COMPLETAR
  print ("{:<15} | {:<8} | {:<15} | {:<20}"
         .format(str(token.text), str(token.dep_), str(token.head.text), str([child for child in token.children])))

# %%
displacy.render(???, style='dep', jupyter=True, options={"distance": 100}) # COMPLETAR

# %% [markdown]
# ### Named Entity Recognition ⚡

# %%
??? = nlp(u'???') # COMPLETAR

# %%
displacy.render(???, style='ent', jupyter=True) # COMPLETAR

# %% [markdown]
# ¿El programa reconoció correctamente todas las entidades de tu oración?

# %% [markdown]
# ### Similitud Textual ⚡

# %%
??? = nlp2("???") #COMPLETAR
??? = nlp2("???") #COMPLETAR

# %%
print(???, "<->", ???, ???.similarity(???)) #COMPLETAR

# %% [markdown]
# Hemos concluido nuestra clase de spaCy con 4 de tareas comunes que se realizan en NLP. ¿Cuál te ha gustado más? ¿Cuál te serviría para tu trabajo e investigación?
