# %% [markdown]
# ## Entrena aquí tu propio clasificador
# Utiliza este notebook para entrenar y evaluar un clasificador de ML con tus propios datos. Recuerda los pasos que necesarios para crear un modelo:
#
# 1. recolectar tus datos de Twitter
# 2. preprocesar tus datos
# 3. anotación con los features o labels
# 4. entrenar tu modelo
# 5. evaluación del modelo
#
# No olvides utilizar todos los notebooks que hemos visto en clase. Reutiliza las líneas de código y adáptalas para tus datos.
